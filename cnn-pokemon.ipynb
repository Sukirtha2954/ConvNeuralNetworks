# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
data=pd.read_csv('/kaggle/input/pokemon-images-and-types/pokemon.csv')
data
# Out:
#             Name     Type1   Type2   Evolution
# 0      bulbasaur     Grass  Poison     ivysaur
# 1        ivysaur     Grass  Poison    venusaur
# 2       venusaur     Grass  Poison         NaN
# 3     charmander      Fire     NaN  charmeleon
# 4     charmeleon      Fire     NaN   charizard
# ..           ...       ...     ...         ...
# 804    stakataka      Rock   Steel         NaN
# 805  blacephalon      Fire   Ghost         NaN
# 806      zeraora  Electric     NaN         NaN
# 807       meltan     Steel     NaN         NaN
# 808     melmetal     Steel     NaN         NaN
#
# [809 rows x 4 columns]

# %%
data.value_counts('Type1')
# Out:
# Type1
# Water       114
# Normal      105
# Grass        78
# Bug          72
# Fire         53
# Psychic      53
# Rock         46
# Electric     40
# Poison       34
# Ground       32
# Fighting     29
# Dark         29
# Ghost        27
# Dragon       27
# Steel        26
# Ice          23
# Fairy        18
# Flying        3
# Name: count, dtype: int64

# %%
data=data[data.Type1.isin(['Water','Grass','Fire'])][['Name','Type1']]
data
# Out:
#             Name  Type1
# 0      bulbasaur  Grass
# 1        ivysaur  Grass
# 2       venusaur  Grass
# 3     charmander   Fire
# 4     charmeleon   Fire
# ..           ...    ...
# 778      bruxish  Water
# 786    tapu-bulu  Grass
# 787    tapu-fini  Water
# 797      kartana  Grass
# 805  blacephalon   Fire
#
# [245 rows x 2 columns]

# %%
print('Data shape',data.shape)
print('Number of unique names',data.Name.nunique())
# Out:
# Data shape (245, 2)
# Number of unique names 245

# %%
import os
import pandas as pd
import cv2

image_df=[]

path_start='/kaggle/input/pokemon-images-and-types/images'
for filename in os.listdir(path_start):
    if filename.endswith(".png"):
        image_name = filename.split('.')[0]  
        
        image = cv2.imread(os.path.join(path_start, filename))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
#         image_df=image_df.append({'Name':image_name,'img':np.array(image)},ignore_index=True)
#         image_df=pd.concat
        image_df.append({'Name':image_name,'img':np.array(image)})

image_df=pd.DataFrame(image_df)

# %%
data=data.merge(image_df,how='inner', on='Name')

# %%
data.value_counts('Type1')
# Out:
# Type1
# Water    114
# Grass     78
# Fire      53
# Name: count, dtype: int64

# %%
data.loc[0].img.shape
# Out:
# (120, 120, 3)

# %%
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(data.loc[i*5].img)
    plt.title(f"{data.loc[i*5].Name},{data.loc[i*5].Type1}")
    plt.axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X=np.array(data['img'].tolist(), dtype = np.float32)/255.0
y=data['Type1']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)


augmented_images = []
augmented_labels = []


for i in range(len(X)):
    image = X[i]
    label = y[i]
    image = np.expand_dims(image, axis=0)
    label = np.array([label])
    augmented_images_batch, augmented_labels_batch = [], []
    j=0
    for x_batch, y_batch in datagen.flow(image, label, batch_size=4):
        augmented_images_batch.extend(x_batch)
        augmented_labels_batch.extend(y_batch)
        j+=1
        if j>3:
            break
    augmented_images.extend(augmented_images_batch)
    augmented_labels.extend(augmented_labels_batch)

augmented_images = np.array(augmented_images)
augmented_labels = np.array(augmented_labels)

# %%
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(augmented_images[i*10])
    plt.title(f"{augmented_labels[i*10]}")
    plt.axis('off')
plt.show()

# %%
labels_dict={'Water': 0, 'Grass': 1, 'Fire': 2}


y_final = []
for yi in y:
    y_final.append(labels_dict[yi])


X_train, X_test, y_train, y_test=train_test_split(X,y_final, test_size=.2)

X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(120, 120, 3), 
                  kernel_regularizer=tf.keras.regularizers.l2(l2=0.01)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', 
                  kernel_regularizer=tf.keras.regularizers.l2(l2=0.01)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', 
                  kernel_regularizer=tf.keras.regularizers.l2(l2=0.01)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(3, activation='softmax')
])

cnn.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 118, 118, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 59, 59, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 59, 59, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 57, 57, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 26, 26, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 13, 13, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 21632)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,769,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,862,659 (10.92 MB)
#  Trainable params: 2,862,659 (10.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
histor=cnn.fit(X_train, y_train, epochs=20, validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 484ms/step - accuracy: 0.2750 - loss: 2.5681 - val_accuracy: 0.3673 - val_loss: 2.2704
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 438ms/step - accuracy: 0.4561 - loss: 2.2002 - val_accuracy: 0.3673 - val_loss: 2.0818
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 438ms/step - accuracy: 0.4459 - loss: 1.9818 - val_accuracy: 0.3673 - val_loss: 1.9087
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 498ms/step - accuracy: 0.4899 - loss: 1.7667 - val_accuracy: 0.3673 - val_loss: 1.6836
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - accuracy: 0.5133 - loss: 1.5405 - val_accuracy: 0.4082 - val_loss: 1.4964
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - accuracy: 0.6727 - loss: 1.3284 - val_accuracy: 0.3673 - val_loss: 1.6213
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 433ms/step - accuracy: 0.6037 - loss: 1.2538 - val_accuracy: 0.5918 - val_loss: 1.2459
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 436ms/step - accuracy: 0.6818 - loss: 1.1561 - val_accuracy: 0.5918 - val_loss: 1.1954
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 431ms/step - accuracy: 0.7412 - loss: 1.0391 - val_accuracy: 0.5306 - val_loss: 1.2586
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 427ms/step - accuracy: 0.6779 - loss: 1.0161 - val_accuracy: 0.6531 - val_loss: 1.0928
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 433ms/step - accuracy: 0.7947 - loss: 0.8955 - val_accuracy: 0.5714 - val_loss: 1.1786
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 500ms/step - accuracy: 0.7884 - loss: 0.8874 - val_accuracy: 0.6327 - val_loss: 1.0517
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - accuracy: 0.7715 - loss: 0.8035 - val_accuracy: 0.4898 - val_loss: 1.3437
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.7812 - loss: 0.8078 - val_accuracy: 0.6122 - val_loss: 1.0251
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - accuracy: 0.7964 - loss: 0.6941 - val_accuracy: 0.6327 - val_loss: 1.0516
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - accuracy: 0.8550 - loss: 0.5956 - val_accuracy: 0.6327 - val_loss: 1.0764
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - accuracy: 0.8423 - loss: 0.5735 - val_accuracy: 0.5918 - val_loss: 1.1638
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 433ms/step - accuracy: 0.8709 - loss: 0.5472 - val_accuracy: 0.6122 - val_loss: 1.0797
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 462ms/step - accuracy: 0.9448 - loss: 0.4473 - val_accuracy: 0.5918 - val_loss: 1.1927
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 484ms/step - accuracy: 0.9444 - loss: 0.3974 - val_accuracy: 0.6327 - val_loss: 1.1897

# %%
plt.plot(histor.history['accuracy'])
plt.plot(histor.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])
